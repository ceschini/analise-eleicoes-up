# %%
import pandas as pd

# %%
df = pd.read_csv("boletim-urna-2024-01-poa-up.csv")

# %%
col_list = ['NR_ZONA', 'NR_SECAO', 'NR_LOCAL_VOTACAO', 'NR_PARTIDO',
            'QT_APTOS', 'QT_COMPARECIMENTO', 'QT_ABSTENCOES', 'NR_VOTAVEL', 'QT_VOTOS']

df = df[df.columns.intersection(col_list)]

# %%
df
# Out:
#       NR_ZONA  NR_SECAO  NR_LOCAL_VOTACAO  NR_PARTIDO  QT_APTOS  \
# 0         111       223              1350          80       386
# 1         113       405              1635          80       376
# 2         111       250              1341          80       394
# 3         111       270              1597          80       380
# 4         113       117              1104          80       390
# ...       ...       ...               ...         ...       ...
# 2522      111       132              1562          80       303
# 2523        2       227              1368          80       341
# 2524        2       157              1090          80       330
# 2525        1       225              1589          80       362
# 2526        2       312              1791          80       320
#
#       QT_COMPARECIMENTO  QT_ABSTENCOES  NR_VOTAVEL  QT_VOTOS
# 0                   295             91       80000         1
# 1                   244            132       80000         1
# ...

# %%
df['NR_SECAO'].value_counts()
# Out:
# NR_SECAO
# 7      15
# 411    12
# 94     12
# 34     12
# 143    11
#        ..
# 67      1
# 263     1
# 439     1
# 347     1
# 586     1
# Name: count, Length: 556, dtype: int64

# %%
df['NR_ZONA'].value_counts()
# Out:
# NR_ZONA
# 2      352
# 1      340
# 113    276
# 112    268
# 158    239
# 111    228
# 160    212
# 159    208
# 114    208
# 161    196
# Name: count, dtype: int64
